# %% [markdown]
# <a href="https://colab.research.google.com/github/takakurahashi/github.io/blob/master/felica_worldcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -y install fonts-ipafont-gothic
# フォントを入れる作業
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-ipafont-mincho
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-ipafont-mincho
# 0 upgraded, 2 newly installed, 0 to remove and 22 not upgraded.
# Need to get 8,251 kB of archives.
# After this operation, 28.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3,526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-ipafont-mincho all 00303-18ubuntu1 [4,725 kB]
# Fetched 8,251 kB in 1s (7,248 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 144618 files and directories currently installed.)
# Preparing to unpack .../fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# ...

# %%
# !ls /usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf
# Out:
# /usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Read the whole text.
text = open('/content/sample_data/web.txt').read()

# Generate a word cloud image
# wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:



# lower max_font_size
fpath = '/usr/share/fonts/opentype/ipafont-gothic/ipagp.ttf'
wordcloud = WordCloud(font_path=fpath, max_font_size=40, width=900, height=500).generate(text)

plt.figure(figsize=(15,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
